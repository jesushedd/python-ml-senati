# %%
import pandas as pd

# %%
telecom_df1 = pd.read_csv('./telecom.csv')
telecom_df1
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 2661                      0              134.7               98
# 2662                     36              156.2               77
# 2663                      0              231.1               57
# 2664                      0              180.8              109
# 2665                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 2661             22.90              189.7               68             16.12
# 2662             26.55              215.5              126             18.32
# 2663             39.29              153.4               55             13.04
# 2664             30.74              288.8               58             24.55
# 2665             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 2661                221.4                128                9.96
# 2662                279.1                 83               12.56
# 2663                191.3                123                8.61
# 2664                191.9                 91                8.64
# 2665                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 2661                11.8                 5               3.19
# 2662                 9.9                 6               2.67
# 2663                 9.6                 4               2.59
# 2664                14.1                 6               3.81
# 2665                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 2661                       2  False
# 2662                       2  False
# 2663                       3  False
# 2664                       2  False
# 2665                       0  False
#
# [2666 rows x 20 columns]

# %%
telecom_df2 = pd.read_csv('./telecom2.csv')
telecom_df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
datos_personales = telecom_df2.sample(len(telecom_df1))
datos_operativos = telecom_df1.copy()

# %%
datos_personales.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1666  8388-DMKAE  Female              0      No         No       8
# 1170  9127-FHJBZ    Male              0     Yes        Yes      72
# 4988  1439-LCGVL  Female              0     Yes         No      26
# 676   2324-AALNO  Female              0      No         No      48
# 658   4464-JCOLN    Male              0     Yes        Yes       2
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 1666          Yes            No              No  No internet service  ...
# 1170          Yes           Yes     Fiber optic                  Yes  ...
# 4988          Yes            No              No  No internet service  ...
# 676           Yes           Yes              No  No internet service  ...
# 658           Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1666  No internet service  No internet service  No internet service
# 1170                  Yes                  Yes                  Yes
# 4988  No internet service  No internet service  No internet service
# 676   No internet service  No internet service  No internet service
# 658   No internet service  No internet service  No internet service
#
#           StreamingMovies  Contract PaperlessBilling  \
# 1666  No internet service  Two year               No
# 1170                  Yes  Two year              Yes
# 4988  No internet service  One year               No
# 676   No internet service  One year               No
# 658   No internet service  One year               No
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 1666               Mailed check          20.25        174.65    No
# 1170           Electronic check         114.00       8093.15    No
# 4988               Mailed check          19.20         459.6    No
# 676   Bank transfer (automatic)          24.55       1203.95    No
# 658                Mailed check          19.85          35.9   Yes
#
# [5 rows x 21 columns]

# %%
datos_personales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2666 entries, 4388 to 2572
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2666 non-null   object
#  1   gender            2666 non-null   object
#  2   SeniorCitizen     2666 non-null   int64
#  3   Partner           2666 non-null   object
#  4   Dependents        2666 non-null   object
#  5   tenure            2666 non-null   int64
#  6   PhoneService      2666 non-null   object
#  7   MultipleLines     2666 non-null   object
#  8   InternetService   2666 non-null   object
#  9   OnlineSecurity    2666 non-null   object
#  10  OnlineBackup      2666 non-null   object
#  11  DeviceProtection  2666 non-null   object
#  12  TechSupport       2666 non-null   object
#  13  StreamingTV       2666 non-null   object
#  14  StreamingMovies   2666 non-null   object
#  15  Contract          2666 non-null   object
#  16  PaperlessBilling  2666 non-null   object
#  17  PaymentMethod     2666 non-null   object
#  18  MonthlyCharges    2666 non-null   float64
#  19  TotalCharges      2666 non-null   object
#  20  Churn             2666 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 458.2+ KB

# %%
datos_personales.InternetService.unique()
# Out:
# array(['No', 'Fiber optic', 'DSL'], dtype=object)

# %%
datos_personales.Partner.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
datos_personales.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
datos_personales.describe(include=object)
# Out:
#         customerID  gender Partner Dependents PhoneService MultipleLines  \
# count         2666    2666    2666       2666         2666          2666
# unique        2666       2       2          2            2             3
# top     3525-DVKFN  Female      No         No          Yes            No
# freq             1    1339    1369       1853         2406          1273
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             2666           2666         2666             2666
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              1158           1309         1160             1185
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         2666        2666            2666            2666
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# freq          1300        1042            1038            1474
#
#        PaperlessBilling     PaymentMethod TotalCharges Churn
# count              2666              2666         2666  2666
# unique                2                 4         2574     2
# top                 Yes  Electronic check         20.3    No
# freq               1568               938            5  1962

# %%
pd.get_dummies(datos_personales.gender, drop_first=Tr)
# Out:
#       Female   Male
# 4388    True  False
# 373     True  False
# 5518   False   True
# 6775   False   True
# 1961    True  False
# ...      ...    ...
# 6766   False   True
# 3471    True  False
# 5521   False   True
# 6751   False   True
# 2572    True  False
#
# [2666 rows x 2 columns]

# %%
datos_operativos.sample(5)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2205    TX              90        415                Yes             Yes
# 1612    SD              93        510                 No              No
# 710     DC             108        408                 No             Yes
# 2194    HI             101        415                 No             Yes
# 2401    AZ              69        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2205                     26              169.0              104
# 1612                      0              328.1              106
# 710                      35              215.9              106
# 2194                     24              114.1               95
# 2401                     31              194.9               63
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2205             28.73              188.8              104             16.05
# 1612             55.78              151.7               89             12.89
# 710              36.70              200.6              107             17.05
# 2194             19.40              161.5               86             13.73
# 2401             33.13              191.6               90             16.29
#
#       Total night minutes  Total night calls  Total night charge  \
# 2205                213.3                 76                9.60
# 1612                303.5                114               13.66
# 710                 195.4                107                8.79
# 2194                176.3                 90                7.93
# 2401                153.0                129                6.89
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 2205                13.3                 3               3.59
# 1612                 8.7                 3               2.35
# 710                 15.5                 7               4.19
# 2194                13.0                 9               3.51
# 2401                13.2                 2               3.56
#
#       Customer service calls  Churn
# 2205                       0   True
# 1612                       1   True
# 710                        0  False
# 2194                       2  False
# 2401                       2  False

# %%
datos_operativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
#  14  Total night charge      2666 non-null   float64
#  15  Total intl minutes      2666 non-null   float64
#  16  Total intl calls        2666 non-null   int64
#  17  Total intl charge       2666 non-null   float64
#  18  Customer service calls  2666 non-null   int64
#  19  Churn                   2666 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 398.5+ KB

# %%
datos_operativos['International plan'] = [1 if dato == 'Yes' else 0 for dato in  datos_operativos['International plan'] ]

# %%
datos_operativos['Voice mail plan'] = [1 if dato == 'Yes' else 0 for dato in  datos_operativos['Voice mail plan'] ]
