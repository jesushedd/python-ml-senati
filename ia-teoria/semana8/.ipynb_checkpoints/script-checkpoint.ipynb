# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import heapq

# %% [markdown]
# 1. Seleccionar tres symbols de symbols_valid_meta_data
# 2. Buscar esos symbols.csv en carpeta stocks
# 3. analizar esos stocks

# %%
carpeta_stocks = Path().resolve() / 'stocks/'

# %%
#Buscar los 3 archivos csv con mas datos
csv_mas_grandes = []
for root, dirs, files in carpeta_stocks.walk(on_error=print):
    for file in files:
        fullpath = (root / file)
        file_size = fullpath.stat().st_size
        if len(csv_mas_grandes) < 10:
            heapq.heappush(csv_mas_grandes, (file_size, fullpath, fullpath.stem))
        else:
            if file_size > csv_mas_grandes[0][0]:
                heapq.heapreplace(csv_mas_grandes, (file_size, fullpath, fullpath.stem))

# %%
csv_mas_grandes
# Out:
# [(1395395,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/MRO.csv'),
#   'MRO'),
#  (1473467,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/BA.csv'),
#   'BA'),
#  (1446208,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/KO.csv'),
#   'KO'),
#  (1606023,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/AA.csv'),
#   'AA'),
#  (1582969,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/IP.csv'),
#   'IP'),
#  (1485206,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/MO.csv'),
#   'MO'),
#  (1667253,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/HPQ.csv'),
#   'HPQ'),
#  (1641325,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/DIS.csv'),
#   'DIS'),
#  (1607461,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/ARNC.csv'),
#   'ARNC'),
#  (1644738,
#   WindowsPath('C:/Users/Alumno/Documents/victor-he/ia-teoria/semana8/dea_acciones/stocks/GE.csv'),
#   'GE')]

# %%
primero_GE = pd.read_csv(csv_mas_grandes[-1][1])
segundo_HPQ = pd.read_csv(csv_mas_grandes[-2][1])
tercero_DIS = pd.read_csv(csv_mas_grandes[-3][1])

# %%
primero_GE.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1962-01-02  0.751202  0.763722  0.743690  0.748698   0.001782  2156500
# 1  1962-01-03  0.744942  0.744942  0.738682  0.741186   0.001764  1477600
# 2  1962-01-04  0.741186  0.747446  0.726162  0.732422   0.001743  1837000
# 3  1962-01-05  0.732422  0.733674  0.701122  0.713642   0.001698  2725600
# 4  1962-01-08  0.713642  0.713642  0.691106  0.712390   0.001695  3095000

# %%
primero_GE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14663 entries, 0 to 14662
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       14663 non-null  object
#  1   Open       14663 non-null  float64
#  2   High       14663 non-null  float64
#  3   Low        14663 non-null  float64
#  4   Close      14663 non-null  float64
#  5   Adj Close  14663 non-null  float64
#  6   Volume     14663 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 802.0+ KB

# %%
primero_GE['Date'] = pd.to_datetime(primero_GE.Date)

# %%
plt.plot(primero_GE.Date, primero_GE.Close)

# %%
primero_GE['reg_log'] =  np.log(primero_GE.Close.shift(-1) / primero_GE.Close)

# %%
primero_GE.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close   Volume  \
# 0 1962-01-02  0.751202  0.763722  0.743690  0.748698   0.001782  2156500
# 1 1962-01-03  0.744942  0.744942  0.738682  0.741186   0.001764  1477600
# 2 1962-01-04  0.741186  0.747446  0.726162  0.732422   0.001743  1837000
# 3 1962-01-05  0.732422  0.733674  0.701122  0.713642   0.001698  2725600
# 4 1962-01-08  0.713642  0.713642  0.691106  0.712390   0.001695  3095000
#
#     reg_log
# 0 -0.010084
# 1 -0.011895
# 2 -0.025975
# 3 -0.001756
# 4  0.005259

# %%
def volatilidad(df):
    try:
        df['reg_log']
        pass
    except KeyError:
        df['reg_log'] =  np.log(df.Close.shift(-1) / df.Close)
    return df.reg_log.std()
    
def crecimiento_continuo_promedio(df):
    try: 
        df['reg_log']
        pass
    except KeyError:
        df['reg_log'] =  np.log(df.Close.shift(-1) / df.Close)
    return df.reg_log.mean()

# %%
fecha_corte_5_años = primero_GE.Date.iloc[-1] - pd.DateOffset(years=5)

# %%
tabla_simbolos = pd.read_csv('symbols_valid_meta.csv')
tabla_simbolos
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 0                Y      A            Agilent Technologies, Inc. Common Stock
# 1                Y     AA                    Alcoa Corporation Common Stock
# 2                Y   AAAU                       Perth Mint Physical Gold ETF
# 3                Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4                Y   AADR                AdvisorShares Dorsey Wright ADR ETF
# ...            ...    ...                                                ...
# 8044             Y    ZUO                   Zuora, Inc. Class A Common Stock
# 8045             Y    ZVO                          Zovio Inc. - Common Stock
# 8046             Y   ZYME                       Zymeworks Inc. Common Shares
# 8047             Y   ZYNE       Zynerba Pharmaceuticals, Inc. - Common Stock
# 8048             Y   ZYXI                         Zynex, Inc. - Common Stock
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                   N                   N           100.0          N
# 1                   N                   N           100.0          N
# 2                   P                   Y           100.0          N
# 3                   Q               G   N           100.0          N
# 4                   P                   Y           100.0          N
# ...               ...             ...  ..             ...        ...
# 8044                N                   N           100.0          N
# 8045                Q               Q   N           100.0          N
# 8046                N                   N           100.0          N
# 8047                Q               G   N           100.0          N
# 8048                Q               S   N           100.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0                 NaN          A             A          N
# 1                 NaN         AA            AA          N
# 2                 NaN       AAAU          AAAU          N
# 3                   N        NaN          AACG          N
# 4                 NaN       AADR          AADR          N
# ...               ...        ...           ...        ...
# 8044              NaN        ZUO           ZUO          N
# 8045                N        NaN           ZVO          N
# 8046              NaN       ZYME          ZYME          N
# 8047                N        NaN          ZYNE          N
# 8048                N        NaN          ZYXI          N
#
# [8049 rows x 12 columns]

# %%
[simbolo for _,ruta, simbolo in csv_mas_grandes]
# Out:
# ['MRO', 'BA', 'KO', 'AA', 'IP', 'MO', 'HPQ', 'DIS', 'ARNC', 'GE']

# %%
resumen = tabla_simbolos[tabla_simbolos.Symbol.isin(simbolo for _,ruta, simbolo in csv_mas_grandes)].copy()
resumen['volatilidad'] = np.nan
resumen['crecimiento_continuo_promedio'] = np.nan

# %%
for _, ruta, simbolo in csv_mas_grandes:
    historico = pd.read_csv(ruta)
    crecimiento = crecimiento_continuo_promedio(historico)
    
    resumen.loc[resumen.Symbol == simbolo, 'crecimiento_continuo_promedio'] = crecimiento

# %%
resumen
# Out:
#      Nasdaq Traded Symbol                             Security Name  \
# 1                Y     AA           Alcoa Corporation Common Stock
# 445              Y   ARNC         Arconic Corporation Common Stock
# 604              Y     BA         Boeing Company (The) Common Stock
# 1801             Y    DIS    Walt Disney Company (The) Common Stock
# 2950             Y     GE     General Electric Company Common Stock
# 3407             Y    HPQ                      HP Inc. Common Stock
# 3790             Y     IP  International Paper Company Common Stock
# 4184             Y     KO      Coca-Cola Company (The) Common Stock
# 4722             Y     MO                        Altria Group, Inc.
# 4772             Y    MRO     Marathon Oil Corporation Common Stock
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 1                   N                   N           100.0          N
# 445                 N                   N           100.0          N
# 604                 N                   N           100.0          N
# 1801                N                   N           100.0          N
# 2950                N                   N           100.0          N
# 3407                N                   N           100.0          N
# 3790                N                   N           100.0          N
# 4184                N                   N           100.0          N
# 4722                N                   N           100.0          N
# 4772                N                   N           100.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares  volatilidad  \
# 1                 NaN         AA            AA          N          NaN
# 445               NaN       ARNC          ARNC          N          NaN
# 604               NaN         BA            BA          N          NaN
# 1801              NaN        DIS           DIS          N          NaN
# 2950              NaN         GE            GE          N          NaN
# 3407              NaN        HPQ           HPQ          N          NaN
# 3790              NaN         IP            IP          N          NaN
# 4184              NaN         KO            KO          N          NaN
# 4722              NaN         MO            MO          N          NaN
# 4772              NaN        MRO           MRO          N          NaN
#
#       crecimiento_continuo_promedio
# 1                         -0.000003
# 445                        0.000052
# 604                        0.000346
# 1801                       0.000473
# 2950                       0.000153
# 3407                       0.000326
# 3790                       0.000084
# 4184                       0.000346
# 4722                       0.000360
# 4772                      -0.000048
