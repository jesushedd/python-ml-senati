# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
a = np.array([['hola']])

# %%
'hola' in  a
# Out:
# True

# %%
a.flatten().tolist()
# Out:
# ['hola']

# %%
for hoja in produccion_por_distritos.values():
    fila =  hoja.loc[2:4].to_numpy()
    #print(fila)
    provincia = fila[0][4] if isinstance(fila[0][4],str ) else np.nan
    distrito = fila[1][4] if isinstance(fila[1][4],str) else np.nan
    
    #print(provincia)
    #print(distrito)
    #print('----')

    inicio_tabla = 4 if not  isinstance(distrito, str) else 5

    print(hoja)
    #print(hoja.loc[inicio_tabla:10])
# Out:
#                                                     0             1    2   \
# 0    CEDULA DE PRINCIPALES CULTIVOS, SEGÚN  DISTRIT...           NaN  NaN
# 1                                             REGION :           NaN  NaN
# 2                                          PROVINCIA :           NaN  NaN
# 3                                           DISTRITO :           NaN  NaN
# 4                                                  NaN           NaN  NaN
# ..                                                 ...           ...  ...
# 96                                                  13  MELOCOTONERO    5
# 97                                                  14       NARANJA   30
# 98                                                  15         OLIVO  962
# 99                                                  16         PERAL    4
# 100                                                 17           VID   42
#
#       3      4   5    6    7    8      9    10
# ...

# %%
hoja
# Out:
#                                                    0                   1   \
# 0   CEDULA DE PRINCIPALES CULTIVOS, SEGÚN  DISTRIT...                 NaN
# 1                                            REGION :                 NaN
# 2                                         PROVINCIA :                 NaN
# 3                                           DISTRITO:                 NaN
# 4                                                 NaN                 NaN
# 5                                          NRO. ORDEN             CULTIVO
# 6                                                 NaN                 NaN
# 7                                    TOTAL DISTRITAL:                 NaN
# 8                               CULTIVOS TRANSITORIOS                 NaN
# 9                                                   1  ARVEJA GRANO VERDE
# 10                                                  2    HABA GRANO VERDE
# 11                                                  3       MAIZ AMILACEO
# ...

# %%
variables_meteorologicas = pd.read_csv('meteorologicas.csv')
variables_meteorologicas
# Out:
#             ID           ESTACION     FECHA    HORA  LONGITUD  LATITUD  \
# 0            1          CANDARAVE  20150101       0  -70.2541  -17.268
# 1            2          CANDARAVE  20150101   10000  -70.2541  -17.268
# 2            3          CANDARAVE  20150101   20000  -70.2541  -17.268
# 3            4          CANDARAVE  20150101   30000  -70.2541  -17.268
# 4            5          CANDARAVE  20150101   40000  -70.2541  -17.268
# ...        ...                ...       ...     ...       ...      ...
# 416268  416269  SAN_JOSE_DE_UZUNA  20240630  190000  -71.3284  -16.581
# 416269  416270  SAN_JOSE_DE_UZUNA  20240630  200000  -71.3284  -16.581
# 416270  416271  SAN_JOSE_DE_UZUNA  20240630  210000  -71.3284  -16.581
# 416271  416272  SAN_JOSE_DE_UZUNA  20240630  220000  -71.3284  -16.581
# 416272  416273  SAN_JOSE_DE_UZUNA  20240630  230000  -71.3284  -16.581
#
#         ALTITUD  TEMP    HR   PP   RED DEPARTAMENTO  PROVINCIA   DISTRITO  \
# ...
