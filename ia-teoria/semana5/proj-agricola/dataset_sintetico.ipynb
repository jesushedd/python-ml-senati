# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path

# %%
nombre_columnas = [ 'PRODUCCION ANUAL (t)', 'SUPERFICIE CULTIVADA TOTAL ha', 'SUPERFICIE CULTIVADA COSECHADA ha', 'RENDIMIENTO (kg x ha)', 'PRECIO EN CHACRA (S/ x Kg)' ]
carpeta_datos = Path().resolve() / 'produccion_distritos_csvs/'

# %%
test_csv = carpeta_datos / 'tarata_2021.csv'

# %%
pd.read_csv(test_csv, sep=';', skiprows=4)
# Out:
#                NRO. ORDEN             CULTIVO PRODUCCION ANUAL (t)  \
# 0                     NaN                 NaN                  NaN
# 1       TOTAL PROVINCIAL:                 NaN               52,798
# 2   CULTIVOS TRANSITORIOS                 NaN                  NaN
# 3                      01                 AJO                   18
# 4                      02  ARVEJA GRANO VERDE                  114
# 5                      03    HABA GRANO VERDE                  269
# 6                      04       MAIZ AMILACEO                1,345
# 7                      05         MAIZ CHOCLO                  797
# 8                      06                PAPA                2,787
# 9                      07             ZAPALLO                  250
# 10          EMIPERMANENTE                 NaN                  NaN
# 11                     08             OREGANO                1,991
# 12          S PERMANENTES                 NaN                  NaN
# ...
